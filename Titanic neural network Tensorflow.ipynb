# %% [markdown]
# # **Introduction**

# %% [markdown]
# ***Howdy, Welcome to the Titanic***

# %% [markdown]
# **To whom does this notebook appeal to?**<br><br>
# If you are just starting with WNNC's HELLO FOSS and want to do beginner task in ML, I suggest you start here!
#
# Run this notebook once and you can see the accuracy of this model is mere 61% :(
#
# Data reading, visualization and pre-processing has been done for you. We need you to tune the hypreparameters so as to improve its accuracy and bring it above **80%**. Head over to [this cell](#main) to make the nececsaary changes. Afterwards graphically visualise your training and validation accuracy with each epoch [here](#main2).

# %% [markdown]
# ![](https://faithmag.com/sites/default/files/styles/article_full/public/2018-09/titanic2.jpg?h=6521bd5e&itok=H8td6QVv)

# %% [markdown]
# **Basic Imports**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

import os
files = [f for f in os.listdir('./titanic/')]
for f in files:
        print(f)

# %% [markdown]
# # Reading In the Data

# %% [markdown]
# We will be first importing the data, and creating copies. I recommend this because it give you access to a clean untouched base file.
# Next, we will be dropping some things that we don't need such as passenger Id and Ticket price

# %%
train_data = pd.read_csv('./train.csv')
test_data = pd.read_csv('./test.csv')
#make a copy so your original data is not touched
train = train_data.copy()
test = test_data.copy()
train.shape
y_train = train['Survived']

#We won't need passenger ID or ticket price for the model! They do not provide much insight on the training.
Id = pd.DataFrame(test['PassengerId'])
train.drop(['PassengerId'], axis = 1, inplace=True)
test.drop(['PassengerId'], axis = 1, inplace=True)
train.drop(['Survived'], axis = 1, inplace=True)
train.drop(['Ticket'], axis = 1, inplace=True)
test.drop(['Ticket'], axis = 1, inplace=True)

# %% [markdown]
# **Let's take a look at our data!**

# %%
train.head()
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch     Fare Cabin Embarked
# 0      1      0   7.2500   NaN        S
# 1      1      0  71.2833   C85        C
# 2      0      0   7.9250   NaN        S
# 3      1      0  53.1000  C123        S
# 4      0      0   8.0500   NaN        S

# %% [markdown]
# **Lets see how many null values there are! We need to fill out these values later.**

# %% [markdown]
# **We see that we have some midding values from age, and a ton missing from cabin**

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar='BuPu')
# Out:
# <AxesSubplot:>

# %%
train.isnull().sum().sort_values(ascending=False)[0:20]
# we can see that cabin is midding a lot of values, and age is tooi!
# Out:
# Cabin       687
# Age         177
# Embarked      2
# Fare          0
# Parch         0
# SibSp         0
# Sex           0
# Name          0
# Pclass        0
# dtype: int64

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# **This is an awesome function I created that preprocesses the data. It does thes following**
#
# * Fills in null values based on mean or mode
# * Drops columns that are missing 50 percent of the data
#
# *You guys are free to copy this for loop for your own projects!*[](http://)

# %%
#clean the train data
for i in list(train.columns):
    dtype = train[i].dtype
    values = 0
    if(dtype == float or dtype == int):
        method = 'mean'
    else:
        method = 'mode'
    if(train[i].notnull().sum() / 891 <= .5):
        train.drop(i, axis = 1, inplace=True)
    elif method == 'mean':
        train[i]=train[i].fillna(train[i].mean())

    else:
        train[i]=train[i].fillna(train[i].mode()[0])

# WE CAN DO THIS FOR THE TEST SET TOO!

#clean the test data
for i in list(test.columns):
    dtype = test[i].dtype
    values = 0
    if(dtype == float or dtype == int):
        method = 'mean'
    else:
        method = 'mode'
    if(test[i].notnull().sum() / 418 <= .5):
        test.drop(i, axis = 1, inplace=True)
    elif method == 'mean':
        test[i]=test[i].fillna(test[i].mean())

    else:
        test[i]=test[i].fillna(test[i].mode()[0])

# %% [markdown]
# **As we can see, all of the missing values are gone!**

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar='BuPu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# **Title**

# %% [markdown]
# Lets take out the Mr, Miss, etc from the name section, and create a new column names title!

# %%
#TITLE

train_test_data = [train, test] # combining train and test dataset

for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)


title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 1, 
                 "Master": 0, "Dr": 1, "Rev": 0, "Col": 0, "Major": 0, "Mlle": 1,"Countess": 1,
                 "Ms": 1, "Lady": 1, "Jonkheer": 1, "Don": 0, "Dona" : 1, "Mme": 0,"Capt": 0,"Sir": 0 }
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %% [markdown]
# **Sex**

# %% [markdown]
# We can make male and female into catagorical variables such as 0 and 1

# %%
    
sex_mapping = {"male": 0, "female":1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %% [markdown]
# **Embarked**

# %% [markdown]
# Lets test to see if there is any correlation with Pclass and Embarked

# %%
Pclass1 = train_data[train_data['Pclass'] == 1]['Embarked'].value_counts()
Pclass2 = train_data[train_data['Pclass'] == 2]['Embarked'].value_counts()
Pclass3 = train_data[train_data['Pclass'] == 3]['Embarked'].value_counts()

df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can assign each embarked value to a numberical value for training later!

# %%
for data in train_test_data:
    data['Embarked'] = data['Embarked'].fillna("S")
    
embarked_mapping = {"S": 0, "C": 1, "Q": 2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %% [markdown]
# **Family Size**

# %% [markdown]
# Parch ( Parent & child ) and Sibsp( Sibling & Spouse ) are both contributing factors to family size, so lets make a new column called family size, and drop the other ones.

# %%
train["FamilySize"] = train['SibSp'] + train['Parch'] + 1
test["FamilySize"] = test['SibSp'] + test['Parch'] + 1

# %% [markdown]
# # **Correlations**

# %%
sns.heatmap(train.corr(),cbar='plasma')
# Out:
# <AxesSubplot:>

# %%
train.drop(['Name'], axis = 1, inplace=True)
test.drop(['Name'], axis = 1, inplace=True)

# %%
train.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  FamilySize
# 0       3    0  22.0      1      0   7.2500         0      0           2
# 1       1    1  38.0      1      0  71.2833         1      1           2
# 2       3    1  26.0      0      0   7.9250         0      1           1
# 3       1    1  35.0      1      0  53.1000         0      1           2
# 4       3    0  35.0      0      0   8.0500         0      0           1

# %%
test.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  FamilySize
# 0       3    0  34.5      0      0   7.8292         2      0           1
# 1       3    1  47.0      1      0   7.0000         0      1           2
# 2       2    0  62.0      0      0   9.6875         2      0           1
# 3       3    0  27.0      0      0   8.6625         0      0           1
# 4       3    1  22.0      1      1  12.2875         0      1           3

# %% [markdown]
# # **PreProcessing**

# %% [markdown]
# **Now that our data looks good, lets get ready to build our models!**

# %%
#imports
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# We should scale the values in the data, so that the neural network can train better!

# %%
continuous = ['Age', 'Fare', 'Parch', 'Pclass', 'SibSp', 'FamilySize']

scaler = StandardScaler()

for var in continuous:
    train[var] = train[var].astype('float64')
    train[var] = scaler.fit_transform(train[var].values.reshape(-1, 1))
for var in continuous:
    test[var] = test[var].astype('float64')
    test[var] = scaler.fit_transform(test[var].values.reshape(-1, 1))

# %%
train.describe(include='all').T
# Out:
#             count          mean       std       min       25%       50%  \
# Pclass      891.0 -8.772133e-17  1.000562 -1.566107 -0.369365  0.827377
# Sex         891.0  3.524130e-01  0.477990  0.000000  0.000000  0.000000
# Age         891.0  2.232906e-16  1.000562 -2.253155 -0.592481  0.000000
# SibSp       891.0  4.386066e-17  1.000562 -0.474545 -0.474545 -0.474545
# Parch       891.0  5.382900e-17  1.000562 -0.473674 -0.473674 -0.473674
# Fare        891.0  3.987333e-18  1.000562 -0.648422 -0.489148 -0.357391
# Embarked    891.0  3.613917e-01  0.635673  0.000000  0.000000  0.000000
# Title       891.0  3.591470e-01  0.480020  0.000000  0.000000  0.000000
# FamilySize  891.0 -2.392400e-17  1.000562 -0.560975 -0.560975 -0.560975
#
#                  75%       max
# Pclass      0.827377  0.827377
# Sex         1.000000  1.000000
# Age         0.407926  3.870872
# SibSp       0.432793  6.784163
# Parch      -0.473674  6.974147
# Fare       -0.024246  9.667167
# Embarked    1.000000  2.000000
# Title       1.000000  1.000000
# FamilySize  0.059160  5.640372

# %% [markdown]
# # **Neural Network**

# %% [markdown]
# <a id='main'></a>
# Here's the model!

# %%
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D,MaxPool2D
from keras.wrappers.scikit_learn import KerasClassifier

tf.keras.optimizers.Adam(
    learning_rate=0.01, name='Adam'
)
#creating a model with sequential columns
model = Sequential()

#flattens the data into a 1d array
model.add(Flatten())
#creates the first latyer with the input dimanetion. 

model.add(Dense(4, input_dim=train.shape[1], activation='relu'))
#next layer with 32 dense nodes
model.add(Dense(32, activation = 'relu'))

#last layer is initiated here
model.add(Dense(4, activation = 'relu'))

# create output layer
    # Feel free to experiment with the activation functions and the optimizers
model.add(Dense(1, activation='sigmoid'))  # output layer
    
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %% [markdown]
# **Let's fit our model!**

# %%
history = model.fit(train, y_train, epochs=50, batch_size=50, validation_split = 0.2)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Layer flatten_7 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 15/15 [==============================] - 0s 26ms/step - loss: 0.6935 - accuracy: 0.6081 - val_loss: 0.6810 - val_accuracy: 0.7430
# Epoch 2/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6811 - accuracy: 0.6770 - val_loss: 0.6697 - val_accuracy: 0.7374
# Epoch 3/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6738 - accuracy: 0.6938 - val_loss: 0.6607 - val_accuracy: 0.7709
# Epoch 4/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6671 - accuracy: 0.7163 - val_loss: 0.6526 - val_accuracy: 0.7765
# Epoch 5/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6612 - accuracy: 0.7247 - val_loss: 0.6449 - val_accuracy: 0.7877
# Epoch 6/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6556 - accuracy: 0.7360 - val_loss: 0.6374 - val_accuracy: 0.8156
# Epoch 7/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6496 - accuracy: 0.7444 - val_loss: 0.6308 - val_accuracy: 0.8101
# Epoch 8/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6441 - accuracy: 0.7584 - val_loss: 0.6237 - val_accuracy: 0.8101
# Epoch 9/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6383 - accuracy: 0.7584 - val_loss: 0.6161 - val_accuracy: 0.8045
# Epoch 10/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6327 - accuracy: 0.7626 - val_loss: 0.6099 - val_accuracy: 0.8156
# Epoch 11/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6269 - accuracy: 0.7711 - val_loss: 0.6029 - val_accuracy: 0.8101
# Epoch 12/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6216 - accuracy: 0.7795 - val_loss: 0.5969 - val_accuracy: 0.8156
# Epoch 13/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6161 - accuracy: 0.7795 - val_loss: 0.5909 - val_accuracy: 0.8101
# Epoch 14/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6103 - accuracy: 0.7879 - val_loss: 0.5845 - val_accuracy: 0.8045
# Epoch 15/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6051 - accuracy: 0.7879 - val_loss: 0.5780 - val_accuracy: 0.8156
# Epoch 16/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5996 - accuracy: 0.7893 - val_loss: 0.5726 - val_accuracy: 0.8156
# Epoch 17/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5948 - accuracy: 0.7893 - val_loss: 0.5679 - val_accuracy: 0.8268
# Epoch 18/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5904 - accuracy: 0.7865 - val_loss: 0.5634 - val_accuracy: 0.8212
# Epoch 19/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5861 - accuracy: 0.7935 - val_loss: 0.5590 - val_accuracy: 0.8212
# Epoch 20/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5815 - accuracy: 0.7907 - val_loss: 0.5540 - val_accuracy: 0.8268
# Epoch 21/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5777 - accuracy: 0.7963 - val_loss: 0.5497 - val_accuracy: 0.8268
# Epoch 22/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5735 - accuracy: 0.7963 - val_loss: 0.5454 - val_accuracy: 0.8212
# Epoch 23/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5697 - accuracy: 0.7963 - val_loss: 0.5410 - val_accuracy: 0.8324
# Epoch 24/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5655 - accuracy: 0.7992 - val_loss: 0.5368 - val_accuracy: 0.8324
# Epoch 25/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5620 - accuracy: 0.8006 - val_loss: 0.5334 - val_accuracy: 0.8324
# Epoch 26/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5573 - accuracy: 0.8020 - val_loss: 0.5287 - val_accuracy: 0.8324
# Epoch 27/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5537 - accuracy: 0.8006 - val_loss: 0.5246 - val_accuracy: 0.8324
# Epoch 28/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5500 - accuracy: 0.8020 - val_loss: 0.5224 - val_accuracy: 0.8324
# Epoch 29/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5465 - accuracy: 0.8006 - val_loss: 0.5180 - val_accuracy: 0.8324
# Epoch 30/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5430 - accuracy: 0.7992 - val_loss: 0.5144 - val_accuracy: 0.8324
# Epoch 31/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5396 - accuracy: 0.8048 - val_loss: 0.5116 - val_accuracy: 0.8324
# Epoch 32/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5366 - accuracy: 0.8048 - val_loss: 0.5089 - val_accuracy: 0.8324
# Epoch 33/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5338 - accuracy: 0.8048 - val_loss: 0.5063 - val_accuracy: 0.8380
# Epoch 34/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5310 - accuracy: 0.8048 - val_loss: 0.5036 - val_accuracy: 0.8324
# Epoch 35/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5284 - accuracy: 0.8048 - val_loss: 0.5007 - val_accuracy: 0.8324
# Epoch 36/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5254 - accuracy: 0.8034 - val_loss: 0.4993 - val_accuracy: 0.8380
# Epoch 37/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5230 - accuracy: 0.8048 - val_loss: 0.4962 - val_accuracy: 0.8380
# Epoch 38/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5202 - accuracy: 0.8048 - val_loss: 0.4932 - val_accuracy: 0.8380
# Epoch 39/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5179 - accuracy: 0.8048 - val_loss: 0.4915 - val_accuracy: 0.8380
# Epoch 40/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5154 - accuracy: 0.8048 - val_loss: 0.4895 - val_accuracy: 0.8324
# Epoch 41/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5130 - accuracy: 0.8090 - val_loss: 0.4872 - val_accuracy: 0.8324
# Epoch 42/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5106 - accuracy: 0.8104 - val_loss: 0.4851 - val_accuracy: 0.8324
# Epoch 43/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5085 - accuracy: 0.8104 - val_loss: 0.4836 - val_accuracy: 0.8324
# Epoch 44/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5064 - accuracy: 0.8118 - val_loss: 0.4819 - val_accuracy: 0.8324
# Epoch 45/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5047 - accuracy: 0.8118 - val_loss: 0.4811 - val_accuracy: 0.8324
# Epoch 46/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5025 - accuracy: 0.8118 - val_loss: 0.4793 - val_accuracy: 0.8324
# Epoch 47/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5008 - accuracy: 0.8132 - val_loss: 0.4780 - val_accuracy: 0.8324
# Epoch 48/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4990 - accuracy: 0.8132 - val_loss: 0.4771 - val_accuracy: 0.8268
# Epoch 49/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4972 - accuracy: 0.8132 - val_loss: 0.4754 - val_accuracy: 0.8268
# Epoch 50/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4956 - accuracy: 0.8146 - val_loss: 0.4741 - val_accuracy: 0.8268

# %%
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 9)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 40
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                160
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 68
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# **Evaluate the model!**

# %%
scores = model.evaluate(train, y_train, batch_size=32)
# Out:
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4904 - accuracy: 0.8171

# %% [markdown]
# **Create Predictions**

# %%
y_pred = model.predict(test)

y_final = (y_pred > 0.5).astype(int).reshape(test.shape[0])

output = pd.DataFrame({'PassengerId': test_data['PassengerId'], 'Survived': y_final})
output.to_csv('prediction-ann.csv', index=False)

# %% [markdown]
# # **Neural Network Analyasis**

# %% [markdown]
# <a id='main2'></a>
# We can plot the loss, and val_loss & acc and val_acc
# The main purpose of this is to make sure the model follows a good trend, and to make sure that you are not overfitteing your model.

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1,51)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
